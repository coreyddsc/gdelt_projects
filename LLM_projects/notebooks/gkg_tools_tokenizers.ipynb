# %%
import os
import re
import pandas as pd
import numpy as np
import requests
from requests.adapters import HTTPAdapter
from requests.packages.urllib3.util.retry import Retry
import json
from datetime import date, datetime, timedelta
from bs4 import BeautifulSoup
import gdelt # for gdelt searchs
from gkg_tools import * # for gkg searchs
# %run "../gkg_tools.py" # using magic command run to access the script from the parent directory


import nltk
from nltk.tokenize import word_tokenize, sent_tokenize


from transformers import pipeline, set_seed
import torch

# GPU Timing (using GPU 1) else -1 for CPU
device_id = 1 if torch.cuda.is_available() else -1
# Out:
# here

# %%
gkg = gkg_operator() # create a gkg operator
# gkg.set_date(['2024 Oct 20', '2024 Oct 21']) # set the date range for the search
# gkg.set_date(['2024 Oct 30']) # set the date range for the search
gkg.get_gkg(coverage=True)
persons = ['Eiichiro Oda', 'Shueisha', 'One Piece']
OP = gkg.gkg_persons(persons)
OP.reset_index(inplace=True)

# url = OP['documentidentifier'].iloc[0]
# url

# %%
gkg.gkg_query.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31349 entries, 0 to 31348
# Data columns (total 27 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   gkgrecordid                 31349 non-null  object
#  1   date                        31349 non-null  int64
#  2   sourcecollectionidentifier  31349 non-null  int64
#  3   sourcecommonname            31349 non-null  object
#  4   documentidentifier          31349 non-null  object
#  5   counts                      3798 non-null   object
#  6   v2counts                    3798 non-null   object
#  7   themes                      27818 non-null  object
#  8   v2themes                    27818 non-null  object
#  9   locations                   24251 non-null  object
#  10  v2locations                 24221 non-null  object
#  11  persons                     24707 non-null  object
#  12  v2persons                   24485 non-null  object
#  13  organizations               21504 non-null  object
#  14  v2organizations             20704 non-null  object
#  15  v2tone                      31349 non-null  object
#  16  dates                       12502 non-null  object
#  17  gcam                        31349 non-null  object
#  18  sharingimage                26993 non-null  object
#  19  relatedimages               4150 non-null   object
#  20  socialimageembeds           2401 non-null   object
#  21  socialvideoembeds           13433 non-null  object
#  22  quotations                  7405 non-null   object
#  23  allnames                    29589 non-null  object
#  24  amounts                     23793 non-null  object
#  25  translationinfo             0 non-null      float64
#  26  extras                      31349 non-null  object
# dtypes: float64(1), int64(2), object(24)
# memory usage: 6.5+ MB

# %%
# store OP in a csv file
# OP.to_csv('OP.csv', index=False)
# OP = pd.read_csv('OP.csv')
# urls = OP['documentidentifier'].tolist()

nrows = 10000
urls = gkg.gkg_query['documentidentifier'].tolist()[:nrows]
parsed_urls = []
for url in urls:
    url = url.replace('https://','').replace('http://','').replace('www.','').split('/')
    # if url is empty string, remove it
    if url[-1] == '':
        url.pop()
    article_title = url[-1]
    article_title = article_title.replace('-',' ')
    article_title = article_title.replace('_',' ')
    url[-1] = article_title
    # keep only first and last element of url
    url = [url[0],url[-1]]
    print(url)
    parsed_urls.append(article_title)

# urls
# Out:
# ['stokesentinel.co.uk', 'hotel issues statement out control 9683785']
# ['lithgowmercury.com.au', '?cs=34616']
# ['sconeadvocate.com.au', '?cs=305']
# ['wknofm.org', 'russian exiles push western countries to support ukraine']
# ['classy100.com', 'rep waltz to newsmax biden wh sends weapons doesnt contain iran']
# ['arxiv.org', '2111.08566']
# ['yasstribune.com.au', '?cs=34616']
# ['echo-news.co.uk', '24696787.russell brand sex offence allegations evidence sent cps']
# ['watoday.com.au', 'scientific soothsayers why us election polls are often right or spectacularly wrong 20241031 p5kmtx.html']
# ['yahoo.com', 'donald trump holds rally gastonia 220710886.html']
# ['wkyt.com', 'kentucky early voter turnout breaks record second day row']
# ['953wdae.iheart.com', '2024 11 02 jets vs lightning time tv live stream 1132024']
# ['en.apa.az', 'israeli commandos nab top hezbollah naval operative in north lebanon raid 452362']
# ['dailykos.com', ' Cartoon Setting back the clock']
# ['gloucesteradvocate.com.au', '?cs=34616']
# ['sthelensstar.co.uk', '24696758.africa holds special place heart says william earthshot ceremony']
# ['kmbc.com', '62793347']
# ['cpfc.co.uk', 'marc guehi reaction wolves crystal palace november 2024']
# ['thenationonlineng.net', 'revolutionary drugs']
# ['edmontonsun.com', '08598886 e144 4493 8a95 0aefeb347daa']
# ['bunburymail.com.au', '?cs=30776']
# ['menafn.com', 'Military Medics Not Being Turned Into Infantry General Staff']
# ['dailykos.com', ' Harris takes lead in Selzer Iowa poll']
# ['kyma.com', 'yuma nightmares haunted house on halloween night']
# ['rollingstone.com', 'cyndi lauper hayley williams girls just wanna have fun nashville 1235151461']
# ['menafn.com', 'JK Court Closes PIL For Regulating Mining Activities In JK']
# ['vindy.com', 'remote learning must be minimized in us']
# ['gdnonline.com:443', 'GATEWAY TO GROWTH The second edition of Gateway Gulf kicks off in Bahrain today ']
# ['fool.com', 'should you buy nvidia stock before nov 20 the evid']
# ['sthelensstar.co.uk', '24691784.disadvantaged pupils going university ever']
# ['couriernews.com', 'article ac4f9834 03c3 5c60 af46 f645a9b64fa7.html']
# ['dailyexcelsior.com', 'shah rukh khan turns 59 fans wait outside mannat to catch superstars glimpse']
# ['cbsnews.com', 'rescue team responds to crash in san joaquin county after car ends up in water']
# ['yasstribune.com.au', '?cs=14264']
# ['rotowire.com', 'espn bet promo code roto claim 1k in bonus bets for cfb nba nfl odds 86749']
# ['news.punchjump.com', 'nintendo switch no 1 in japan oct 27 sales']
# ['cleantechnica.com', 'voting against fascism means respecting civil society and the planet']
# ['gloucesteradvocate.com.au', '?cs=305']
# ['pressofatlanticcity.com', 'article a0cbd4de 9941 11ef 9b06 47a6ec7d4bd4.html']
# ['yahoo.com', 'most americans hardly knew kamala 222730927.html']
# ['cookislandsnews.com', 'public does not want to pay for water says water petition committee']
# ['kmbc.com', '62793171']
# ['watoday.com.au', 'the reason i can be the greatest athlete i can be jessica fox s secret to success 20241018 p5kjik.html']
# ['yardbarker.com', 's1 13132 41167229']
# ['burytimes.co.uk', '24696777.teenage boy charged attempted murder girl 13 stabbed near roadside']
# ['gloucesteradvocate.com.au', '?cs=305']
# ['magic1079.iheart.com', '2024 09 10 the best political podcasts to listen to']
# ['sciencealert.com', 'an unexpected object is blasting powerful radiation in deep space']
# ['classy100.com', 'texas bars doj election monitors from polling sites']
# ['huri.harvard.edu', 'lost in living literary evening with halyna kruk']
# ['isp.netscape.com', 'aaac60ee090e2c4b9a6862f9c88b2467']
# ['dailykos.com', ' Harrison Ford Endorses Harris Walz']
# ['dailykos.com', ' Messaging Breakthrough']
# ['wiba.iheart.com', '2024 11 02 woman convicted of murder while wearing clown mask released from prison']
# ['rsn.net.au', '672057']
# ['powertalk967.iheart.com', '2024 11 02 shark completely severs leg of surfer off coast of hawaii']
# ['southpeacenews.com', 'plans to upgrade outdoor rink at grouard continue']
# ['zerohedge.com', 'there are no watchers rnc sues georgia counties over last minute decision accept weekend']
# ['1150wima.iheart.com', '2024 11 02 woman convicted of murder while wearing clown mask released from prison']
# ['yahoo.com', 'scattered showers throughout day slowly 224105400.html']
# ['thecorner.eu', '117364']
# ['dailykos.com', ' Voting for Decency amp Morality']
# ['yahoo.com', 'blue front fire near ruidoso 215201829.html']
# ['nzherald.co.nz', 'PZEUV43IGRA7XC4Q24SWLSRZMA']
# ['saratogian.com', 'breeders cup roundup immersive impressive in juvenile fillies']
# ['yardbarker.com', 's1 15359 41167330']
# ['bunburymail.com.au', 'cuts for student debt as labor targets young voters']
# ['dailykos.com', ' Now It s Trump Who s Losing Sleep Over the Polls And He ll Lose When He Sees the Iowa Poll']
# ['dailykos.com', ' What s for Dinner v19 18 Arroz con Pollo']
# ['echo-news.co.uk', '24696788.stritcly come dancing 2024 see leaderboard week 7']
# ['dailykos.com', ' Trump will fix it']
# ['winnipegfreepress.com', 'behren morton leads late td drive as texas tech posts 23 22 upset for no 11 cyclones first loss']
# ['seneweb.com', 'sedhiou anta babacar ngom s rsquo engage n 454817.html']
# ['saultstar.com:443', 'sault area hospital declares covid 19 outbreak on 1b unit']
# ['lincolntimesnews.com', 'image ccc8f3e6 2fbe 5523 b5e0 09deed5c6292.html']
# ['voanews.com', '7849055.html']
# ['liverpoolecho.co.uk', 'girl 10 dies after being 30285079']
# ['yahoo.com', 'more details officer involved shooting 213358489.html']
# ['standardspeaker.com', 'team from slovak newspaper report on u s election from hazleton']
# ['yahoo.com', 'opinion why am releasing epstein 231851928.html']
# ['1490wosh.com', 'in person early voting surpasses 2020 by 3 million']
# ['caughtoffside.com', 'mikel arteta newcastle united defeat']
# ['watoday.com.au', 'do yourself a favour check out this countdown 50th anniversary top 10 20241023 p5kksd.html']
# ['railsatscale.com', '2024 10 23 next generation oob gc']
# ['rotowire.com', 'betmgm bonus code grab 250 in bets for texas am clemson tennessee more cfb odds 86748']
# ['ktxs.com', 'candidates scheduled to visit pennsylvania in final days before election']
# ['caughtoffside.com', 'jamie carragher liverpool rivals fun']
# ['wxxv25.com', 'singing river hospice of light tree planting ceremonies']
# ['cagle.com', 'trump stage 2']
# ['yahoo.com', '3 dead helicopter crash louisiana 194331399.html']
# ['foxbangor.com', 'article 5f0d70bd 9e81 50f5 92e8 82aa1774e3a1.html']
# ['yahoo.com', 'breonna taylors civil rights were 230244584.html']
# ['gdnonline.com:443', '1336509']
# ['krwg.org', 'november 2 2024 pbs news weekend full episode 1730520001']
# ['watoday.com.au', 'precious princess health minister warns gps to brace for women s pain inquiry findings 20241031 p5kmsm.html']
# ['oberonreview.com.au', '?cs=34616']
# ['dailykos.com', ' Harris up by 3 in Iowa']
# ['wiba.iheart.com', '2024 11 02 delivery driver rescues woman from her burning home']
# ['stylecaster.com', 'margot robbie baby gender']
# ['yahoo.com', 'most americans hardly knew kamala 222730347.html']
# ['yahoo.com', 'harris widens lead trump virginia 204331061.html']
# ['1150wima.iheart.com', '2024 11 02 delivery driver rescues woman from her burning home']
# ['maldonandburnhamstandard.co.uk', '24696674.gogglebox duo georgia abbie warned dangerous item']
# ['yahoo.com', 'most americans hardly knew kamala 222730178.html']
# ['bostonherald.com', 'its a fight to the finish in races that will determine control of congress']
# ['patriotla.iheart.com', '2024 11 02 jason kelce smashes someones phone after slur about travis']
# ['liverpoolecho.co.uk', 'bbc strictly come dancing sam 30285834']
# ['kyma.com', 'man attempts to evade custody after found guilty of felony offenses in imperial county']
# ['wknofm.org', 'female wildland firefighters organize for more support at work']
# ['dailyexcelsior.com', 'top let comdr among 3 militants killed in kashmir gun battles']
# ['saratogian.com', 'citizen bulls upset win a highlight on day 1 of breeders cup at del mar']
# ['1490wosh.com', 'does wisconsin allow same day voter registration']
# ['watoday.com.au', 'no atar no worries the students finding success without an admission rank 20241001 p5kezb.html']
# ['isp.netscape.com', '53f78ff2c505a277894a55b4cbd8e564']
# ['kmbc.com', '62787307']
# ['yahoo.com', 'noem cuban women shows harris 220933413.html']
# ['cbsnews.com', 'georgia judge republican lawsuit hand returned mail ballots fulton county']
# ['pjmedia.com', 'dems sued for ads threatening be a shame if your career was destroyed because you work for trump n4933896']
# ['swissinfo.ch', '87935901']
# ['yahoo.com', 'south carolinians alternative death penalty 210702307.html']
# ['gloucesteradvocate.com.au', '?cs=34616']
# ['zerohedge.com', 'buffett calls top berkshire dumps 100 million apple shares unprecedented selling spree']
# ['pjmedia.com', 'but dear hes just not our kind n4933892']
# ['krwg.org', 'battleground 1730579212']
# ['powertalk967.iheart.com', '2024 11 02 jason kelce smashes someones phone after slur about travis']
# ['thedailystar.net', 'nagorik committee form upazila chapters 3743171']
# ['newser.com', 'santa muerte cult leader killed at guanajuato altar.html']
# ['stylecaster.com', 'jason kelce smashes phone']
# ['echo-news.co.uk', '24696765.harris trump zero sun belt states final weekend push votes']
# ['ewrestlingnews.com', 'randy orton and kevin owens brawl at wwe crown jewel 2024 match canceled']
# ['times-series.co.uk', '24696758.africa holds special place heart says william earthshot ceremony']
# ['dailykos.com', ' How Trump s hate speech won back the far right and boosted his poll numbers']
# ['liverpoolecho.co.uk', 'urgent recall issued toy sold 30276562']
# ['wcfcourier.com', 'article 2a4ec5f4 9870 11ef bd81 0f9e016d9175.html']
# ['en.apa.az', 'bolivias government accuses supporters of ex president evo morales of taking 200 soldiers hostage 452370']
# ['themarketsdaily.com', 'rareview tax advantaged income etf batsrtai announces dividend of 0 11.html']
# ['saratogian.com', 'breeders cup notebook immersive impressive in juvenile fillies race']
# ['klcc.org', 'russian exiles push western countries to support ukraine']
# ['thisisoxfordshire.co.uk', '24696731.jb gill lauren oakley score joint series highest amy dowden watches']
# ['yahoo.com', 'james o keefe gets warned 223231619.html']
# ['wcfcourier.com', 'article 05ceb5e2 97a6 11ef 9e0c efa34709f1e5.html']
# ['yahoo.com', 'bone marrow drive branford hopes 215434242.html']
# ['srilankasource.com', 'australia pakistan bangladesh sri lanka register semi final spots in hong kong sixes 2024']
# ['lgbtqnation.com', '2184']
# ['yakimaherald.com', 'article 2d45e8fd 6b05 5e1f b841 d418276dcf2e.html']
# ['en.apa.az', 'brazil gp qualifying postponed after heavy rain and lightning at interlagos 452365']
# ['dailyexcelsior.com', 'centre initiates inquiry into the death of 10 elephants in tiger reserve in mp']
# ['home.nzcity.co.nz', 'article.aspx?id=409885']
# ['wflaorlando.iheart.com', '2024 11 02 woman convicted of murder while wearing clown mask released from prison']
# ['thenationonlineng.net', 'tambuwal took sokoto back twenty years dan tsoho']
# ['winnipegfreepress.com', 'hastings larison combine for 6 tds lead uc davis in 59 7 rout over northern colorado']
# ['yahoo.com', 'auburn falls vanderbilt 17 7 213654103.html']
# ['dailyexcelsior.com', 'deaths of 10 newborns shake millions trust in turkeys health care system']
# ['bostonherald.com', 'fan at boston bruins game who slipped and fell in td garden loses negligence case in massachusetts federal appeals court']
# ['lincolntimesnews.com', 'image 280c3ce3 8519 50ac ba72 32a6c0cb2595.html']
# ['thevikingage.com', 'nfl just made terrible sam darnold no call vs rams week 8 worse minnesota vikings']
# ['watoday.com.au', 'yes nationals leader david littleproud flew qantas but he paid his own way 20241017 p5kj68.html']
# ['classy100.com', 'gops boebert losing ground in colo house race']
# ['kmvt.com', 'fit well new ventilators paramedics']
# ['yasstribune.com.au', '?cs=14264']
# ['ukiahdailyjournal.com', 'wesley starritt convicted of two fatal stabbings sentenced to 40 years to life in prison']
# ['liverpoolecho.co.uk', 'bbc strictly come dancings tasha 30286075']
# ['sconeadvocate.com.au', '?cs=305']
# ['wuwf.org', 'russian exiles push western countries to support ukraine']
# ['rnz.co.nz', 'armed group kidnaps more than 200 military personnel and seizes base in central bolivia']
# ['bunburymail.com.au', 'nurse suspended over covid 19 lockdown baby shower']
# ['dailyexcelsior.com', 'devender rana given tearful adieu pm lg cm among others condole demise']
# ['fandompost.com', 'b b bunny bondage manga by kaidou minoda announced']
# ['yahoo.com', 'gateway church announces removal 4 232305122.html']
# ['newser.com', 'robot retrieves melted fuel sample from fukushima reactor.html']
# ['newburytoday.co.uk', 'teenage boy charged with attempted murder after girl 13 stabbed near roadside 131433']
# ['cagle.com', 'drowning spain']
# ['menafn.com', 'US Election 2024 I Wasnt Going To Vote But Kamala Changed My Mind Cardi Bs Powerful Endorsement Of Harris']
# ['standardspeaker.com', 'new exhibit opens at hazleton art league']
# ['cagle.com', 'rfk jr with brainworms trumps health advisor']
# ['newsradio540.iheart.com', '2024 11 02 delivery driver rescues woman from her burning home']
# ['cagle.com', 'trump driving a garbage truck']
# ['maldonandburnhamstandard.co.uk', '24696779.pm declare small boats national security issue']
# ['wpbf.com', '62791773']
# ['foxbangor.com', 'article 66ebe40e 37dd 5df5 9732 676b6411adc8.html']
# ['thespec.com', 'article 4284749b d3a2 5670 ade1 7262b1b9fa8c.html']
# ['powertalk967.iheart.com', '2024 11 02 woman convicted of murder while wearing clown mask released from prison']
# ['sconeadvocate.com.au', '?cs=34616']
# ['menafn.com', '17 Year Partnership Between Subaru And The ASPCA Has Helped Over 134000 Pets']
# ['kcsufm.com', 'promotion directors ella perkins and leah walton will drink milk and water for their last meal']
# ['yahoo.com', 'nc republicans choosing early voting 223049039.html']
# ['aero-news.net', 'EmailArticle.cfm?do=main.textpost&id=7BF1B008 6C68 4DCF 9A8E CC8F6E82B718']
# ['lithgowmercury.com.au', '?cs=34616']
# ['thedmonline.com', 'rebels win big in fayetteville defeat arkansas 63 31']
# ['sthelensstar.co.uk', '24696779.pm declare small boats national security issue']
# ['tivysideadvertiser.co.uk', '24696779.pm declare small boats national security issue']
# ['reporterherald.com', 'thompson valley boys claim 4a state cross country title']
# ['cbsnews.com', 'remains of california natives killed naval training flight to return home']
# ['oberonreview.com.au', '?cs=34616']
# ['foxbangor.com', 'article ce0581fa 815a 55b1 89ff bab3c0c6037a.html']
# ['bostonherald.com', 'debate over abortion creates expensive campaigns for state supreme court seats']
# ['krwg.org', 'trump and harris make last minute stops in north carolina']
# ['yahoo.com', 'pinpoint weather cool dry sunday 214002371.html']
# ['newburytoday.co.uk', 'cps considers charging russell brand over sex offence allegations 131430']
# ['winnipegfreepress.com', 'nearly 200 families separated by us mexico border reunite briefly in annual event']
# ['foxbangor.com', 'article 9a221ea0 eaf3 5892 a765 86296b27bbd4.html']
# ['dailykos.com', ' Harris up 4 in IOWA Seltzer Poll']
# ['1490wosh.com', 'harris slams speaker johnsons proposed semiconductor aid cut']
# ['newsnationnow.com', 'watch bald eagle shows off its butterfly stroke while fishing on oregon coast']
# ['yahoo.com', 'red white blue director why 225935985.html']
# ['times-series.co.uk', '24696777.teenage boy charged attempted murder girl 13 stabbed near roadside']
# ['wallstreet-online.de', '18662931 rosen national trial lawyers encourages wm technology inc investors to secure counsel before deadline securities class action first filed by the firm maps']
# ['1059thex.iheart.com', '2024 11 02 jason kelce smashes someones phone after slur about travis']
# ['newzealandstar.com', 'manjrekar slams decision to move sarfaraz khan to no8 spot in mumbai test']
# ['macleayargus.com.au', '?cs=305']
# ['vindy.com', 'cleaning house at ysu should follow zoldan gift']
# ['foxnews.com', 'colin kaepernick']
# ['oberonreview.com.au', '?cs=9676']
# ['wrjn.com', 'joy and desperation in the fox valley']
# ['cagle.com', 'liz and trump firing squad']
# ['digitaljournal.com', 'article']
# ['fandompost.com', 'final volume spotlight kurage no hone wa ao manga by oimoto']
# ['blueshirtbanter.com', 'rangers practice new lines']
# ['myv101.iheart.com', '2024 09 10 the best political podcasts to listen to']
# ['menafn.com', 'Germany Hands EUR 24M To UNIDO Project Toward Restoring Ukraines Green Industry']
# ['gloucesteradvocate.com.au', '?cs=34616']
# ['fox6now.com', 'milwaukee david gruber halloween costume']
# ['tivysideadvertiser.co.uk', '24696765.harris trump zero sun belt states final weekend push votes']
# ['aero-news.net', 'EmailArticle.cfm?do=main.archive&year=2024&month=11&day=2']
# ['orlp.net', 'breaking hash functions']
# ['theconservativetreehouse.com', 'president trump maga rally salem virginia 400pm edt livestream']
# ['literock959.com', 'oklahoma small town police chief and entire police department resign']
# ['yahoo.com', 'newborn baby girl found dead 230235820.html']
# ['times-series.co.uk', '24696731.jb gill lauren oakley score joint series highest amy dowden watches']
# ['isp.netscape.com', '64cf13cfba32c7321ebe7303413011a3']
# ['dailyexcelsior.com', 'india trashes canadas charges against shah']
# ['saratogian.com', 'nccmbball siena jackson personal 1101']
# ['themarketsdaily.com', 'deepbrain chain dbc reaches market cap of 11 34 million.html']
# ['yahoo.com', 'nc republicans choosing early voting 223049103.html']
# ['classy100.com', 'dick morris to newsmax harris running on not trump']
# ['thenationonlineng.net', 'tax reform bills to be or not to be']
# ['kcsufm.com', 'witching hour wonders the haunting legends of halloween']
# ['wflaorlando.iheart.com', '2024 11 02 shark completely severs leg of surfer off coast of hawaii']
# ['powerupgaming.co.uk', 'roblox overlock weapons values list']
# ['cagle.com', 'trump and harris hanging above ravine']
# ['menafn.com', 'India Trashes Canadas Allegations Against Amit Shah As Absurd And Baseless Warns Of Consequences']
# ['yahoo.com', 'battleground florida hillsborough county state 211856627.html']
# ['cookislandsnews.com', 'te ipukarea society tracking the ioi']
# ['morningsun.net', 'cowboys running back ezekiel elliott will miss game at falcons team doesnt say why,160919']
# ['watoday.com.au', 'qantas flights taken by the political class tens of millions of dollars dearer than competitor 20241102 p5knbe.html']
# ['thedailystar.net', 'bangladesh constitution must be updated prevent autocratic rule 3742971']
# ['echo-news.co.uk', '24696719.cps considers charging russell brand sex offence allegations']
# ['wiba.iheart.com', '2024 11 02 jason kelce smashes someones phone after slur about travis']
# ['menafn.com', 'Vinpearl Woos Indian Luxury Travelers With Strategic Two Pronged Focus Media Outreach Newswire APAC']
# ['kmjnow.com', 'dick morris to newsmax harris running on not trump']
# ['cagle.com', 'trump escalates violent rhetoric']
# ['yahoo.com', 'best tvs under 500 small 230015433.html']
# ['independent.com.mt', 'Harris and Trump focus on Sunbelt states during final weekend push for votes 6736265439']
# ['theguardian.com', 'sadness simmers inside this melbourne hospital ward but its a lifeline for people suffering a mental health crisis']
# ['dailykos.com', ' Breaking News Kamala Harris takes the lead in Iowa']
# ['couriernews.com', 'article 3ac0bb4b 3773 578c 8c71 acf438068e4e.html']
# ['reporterherald.com', 'resurrection christians jackson fagerlin wins 3a state title']
# ['standardspeaker.com', 'president biden campaigns for harris in scranton']
# ['foxbangor.com', 'article 44d0f376 90cf 5097 8b72 566b72c8c2f2.html']
# ['sconeadvocate.com.au', '?cs=305']
# ['tivysideadvertiser.co.uk', '24696739.gavin stacey james corden hints death character']
# ['dailyexcelsior.com', 'trinamool congress will test its strength in six bypolls in bengal']
# ['dailyexcelsior.com', 'maldives budget looking at india to provide generous 1 6 bn mvr in grants']
# ['classy100.com', 'trump at n c rally our crime is through the roof']
# ['channelstv.com', 'mottas juventus up to third with important udinese win']
# ['theconservativetreehouse.com', 'trump staffing 2025']
# ['literock959.com', '2 ohio officers involved in black mans death charged with reckless homicide']
# ['kmbc.com', '62791744']
# ['digitaljournal.com', 'article']
# ['sandiegoreader.com', 'laurence juber train song festival ancient echoes 10000 years of beer']
# ['independent.com.mt', 'Brazilian GP to start 90 minutes earlier than planned with more rain ahead Norris wins sprint race 6736265435']
# ['yahoo.com', 'forney man allegedly provided alcohol 183022842.html']
# ['saratogian.com', 'trainer bob bafferts horses finish 1 2 in 2 million juvenile in breeders cup at del mar']
# ['wuwf.org', 'the uncuffed podcast gives voice to california prisoners']
# ['cookislandsnews.com', 'economist cautions cook islands amid us467m net benefit findings']
# ['wiba.iheart.com', '2024 11 02 shark completely severs leg of surfer off coast of hawaii']
# ['thenationonlineng.net', 'presidency dismisses claims of southwest domination in security appointments']
# ['ewrestlingnews.com', 'indi hartwell posts updated statement on her wwe release bayley reacts']
# ['watoday.com.au', 'indigenous thriller s child stealing spirit conjures horrors of the stolen generation 20241028 p5kly5.html']
# ['caughtoffside.com', 'mikel arteta joelinton newcastle player']
# ['ypradio.org', 'the uncuffed podcast gives voice to california prisoners']
# ['yahoo.com', 'more half eligible voters hillsborough 182738691.html']
# ['thejerseytomatopress.com', 'help protect yourself against pneumococcal pneumonia and invasive pneumococcal disease this,112948']
# ['fool.com', 'billionaire israel englander just tripled his inve']
# ['krwg.org', 'trans in america 1730579108']
# ['1037theq.iheart.com', '2024 09 10 the best political podcasts to listen to']
# ['times-series.co.uk', '24696779.pm declare small boats national security issue']
# ['yahoo.com', 'kamala harris responded protesters interrupting 232121035.html']
# ['dailykos.com', ' GOTV Open Thread Happenings November 2 Saturday Scaries']
# ['gizmodo.com', 'gen v season 2 new cast 2000519789']
# ['classy100.com', 'in person early voting surpasses 2020 by 3 million']
# ['powertalk967.iheart.com', '2024 11 02 delivery driver rescues woman from her burning home']
# ['aero-news.net', 'EmailArticle.cfm?do=main.textpost&id=BAF3FD3E 9009 47C5 85D2 A12D416C23E4']
# ['armstrongeconomics.com', 'trump wins eliminates federal income tax economy booms this is important']
# ['morningsun.net', 'a leader of mexican folk saint cult la santa muerte is killed at an altar to the skeletal figure,160912']
# ['yahoo.com', 'kidnapping suspect used ax fire 213617191.html']
# ['vindy.com', 'sound off readers share their thoughts']
# ['lucumr.pocoo.org', 'make it ephemeral']
# ['cookislandsnews.com', 'deep ocean groundings']
# ['dailyexcelsior.com', 'facebook india online services profit grows 43 pc to rs 505 crore']
# ['thisisoxfordshire.co.uk', '24696779.pm declare small boats national security issue']
# ['androidheadlines.com', 'biden administration questioned after tsmc made chips for huawei.html']
# ['voanews.com', '7849048.html']
# ['bunburymail.com.au', '?cs=30776']
# ['echo-news.co.uk', '24696705.national lottery lotto numbers saturday november 2 2024']
# ['theconservativetreehouse.com', 'president trump was right theyre killing the pets killing the pets new york stasi just killed pnut and fred']
# ['kcsufm.com', 'csu students get resources for halloween children in iowa trick or treat for first time in over 80 years colorado gets 66 million grant for rail']
# ['klcc.org', 'trump and harris make last minute stops in north carolina']
# ['pjmedia.com', 'of course deranged harris supporters harass and threaten the mcdonalds that hosted trump n4933893']
# ['fandompost.com', 'anime limited acquires the eminence in shadow 1st anime season for uk release']
# ['menafn.com', 'Banks Commitment To Foreign Currency Requirements For Import']
# ['yahoo.com', 'nypd police academy vandalized week 232500639.html']
# ['cookislandsnews.com', 'reliving cyclone martin 27 years on']
# ['fox6now.com', 'kenosha county rollover crash woman taken hospital']
# ['ypradio.org', 'russian exiles push western countries to support ukraine']
# ['news.webindia123.com', '4252136.html']
# ['ewrestlingnews.com', 'liv morgan beats nia jax to win wwe crown jewel championship']
# ['asianage.com', 'army begins verification at demchock point 1835077']
# ['m.baidu.com', 's?word=%E7%89%B9%E6%9C%97%E6%99%AE%E7%BE%8E%E5%9B%BD%E5%A4%A7%E9%80%89%E5%89%8D%E5%86%8D%E7%8E%B0%E6%9A%B4%E8%AE%BA&ref=www colorful&st=111041&tn=iphone&from=1014994m&sa=re dl cont hao123 top&key=3ca6bca226acf7383585ef343f27ca8b']
# ['dailykos.com', ' Vance Is More Dangerous Than Trump']
# ['krcrtv.com', 'lassen national forest announces major restoration project for over 100k acres of land']
# ['times-series.co.uk', '24696727.russell brand sex offence allegations evidence sent cps']
# ['oberonreview.com.au', '?cs=34616']
# ['yardbarker.com', 's1 13132 41167228']
# ['expressandstar.com', 'cps considers charging russell brand over sex offence allegations']
# ['echo-news.co.uk', '24696779.pm declare small boats national security issue']
# ['newser.com', 'harris trump have to share as campaigns flood south.html']
# ['yahoo.com', 'most americans hardly knew kamala 222730087.html']
# ['yahoo.com', 'most americans hardly knew kamala 222730619.html']
# ['sthelensstar.co.uk', '24696731.jb gill lauren oakley score joint series highest amy dowden watches']
# ['maldonandburnhamstandard.co.uk', '24696731.jb gill lauren oakley score joint series highest amy dowden watches']
# ['bunburymail.com.au', '?cs=34616']
# ['foxbangor.com', 'article 39a6da3f badd 5167 8bbc 97610a3d658a.html']
# ['sconeadvocate.com.au', 'egypt hosts fatah hamas post war gaza talks']
# ['dailykos.com', ' Another Saurday Night You and Me Against The World']
# ['news.webindia123.com', '4252134.html']
# ['expressandstar.com', 'jb gill and lauren oakley score joint series highest as amy dowden watches']
# ['gdnonline.com:443', '1336508']
# ['menafn.com', 'Industrial Facility Damaged In Dnipropetrovsk Region Amid Russian Attack']
# ['stokesentinel.co.uk', 'live updates raging bonfire forces 9683762']
# ['classy100.com', 'rob bresnahan to newsmax i will help gop keep house majority']
# ['krcrtv.com', 'israeli forces capture senior hezbollah operative in north lebanon']
# ['wifr.com', 'rockford man accused murdering baby taken into custody georgia']
# ['morningsun.net', 'minnesota rallies to defeat no 24 illinois 25 17 for the golden gophers 4th straight win,160918']
# ['metvmall.com', 'europe 72 live 50th anniversary edition cd grateful dead']
# ['thenationonlineng.net', 'maduka okoye i enjoy working with alexis sanchez']
# ['m.baidu.com', 's?word=%E8%A6%83%E6%B5%B7%E6%B4%8B%E7%8A%AF%E8%A7%84%E6%88%90%E7%BB%A9%E8%A2%AB%E5%8F%96%E6%B6%88&ref=www colorful&st=111041&tn=iphone&from=1014994m&sa=re dl cont hao123 top&key=8bbeea3aff8c73358ec5f4f256fbb555']
# ['chicagotribune.com', 'murders surged in the pandemic now in many cities that surge is gone 2']
# ['seneweb.com', 'legislatives thierno alassane sall conda n 454812.html']
# ['reporterherald.com', 'trivially speaking when a knee needs attention its time to multitask']
# ['yakimaherald.com', 'article 353fcf66 97b8 11ef ad05 83e15ce4abd6.html']
# ['cjme.com', 'rams huskies both pull off dramatic wins set up all sask hardy cup']
# ['cagle.com', 'the race that stops a nation']
# ['watoday.com.au', 'men pick up your razors as pitt and clooney show clean shaven faces are back 20241016 p5kivo.html']
# ['cookislandsnews.com', 'thomas wynne what is the 16th island of the cooks']
# ['newsradio540.iheart.com', '2024 11 02 woman convicted of murder while wearing clown mask released from prison']
# ['yahoo.com', 'most americans hardly knew kamala 222730032.html']
# ['foxbangor.com', 'article 0a688893 c682 58fc 8528 5cef306158aa.html']
# ['yahoo.com', 'kamala harris responded protesters interrupting 232121942.html']
# ['watoday.com.au', 'apple intelligence is here but it s not all that smart 20241101 p5kn6d.html']
# ['literock959.com', 'floridas convicted killer clown released from prison']
# ['maldonandburnhamstandard.co.uk', '24696777.teenage boy charged attempted murder girl 13 stabbed near roadside']
# ['newburytoday.co.uk', 'pm to declare small boats a national security issue 131434']
# ['thenationonlineng.net', 'shettima others reiterate importance of credit economy to nigerians']
# ['1490wosh.com', 'gops boebert losing ground in colo house race']
# ['kmjnow.com', 'lewandowski to newsmax election a choice between prosperity debt']
# ['wvtf.org', 'trump and harris make last minute stops in north carolina']
# ['dailyexcelsior.com', 'jammu loses its influential leader']
# ['getsurrey.co.uk', 'people living 100 eat same 30278812']
# ['edmontonsun.com', 'five dead alberta highway crashes']
# ['liverpoolecho.co.uk', 'wednesdays lotto jackpot estimated 52 30286006']
# ['maldonandburnhamstandard.co.uk', '24696688.royal estates to earn millions nhs armed forces state school rents']
# ['montgomery-herald.com', 'article 7e226a71 b108 515f 8e27 92144d398c5e.html']
# ['yahoo.com', 'storm center pm rain moves 212948040.html']
# ['thisisoxfordshire.co.uk', '24696688.royal estates to earn millions nhs armed forces state school rents']
# ['sconeadvocate.com.au', 'harris trump nearly cross paths in north carolina']
# ['thenationonlineng.net', 'rivers drawing far fetched parallels']
# ['foxbangor.com', 'article 00f36977 00c7 5764 9ecc 954bd1b1bff5.html']
# ['gloucesteradvocate.com.au', '?cs=34616']
# ['morningsun.net', 'ward and restrepo rewrite the record book and no 5 miami rallies to down duke 53 31,160917']
# ['expressandstar.com', 'amy dowden says her jb gill and lauren oakley are strictly dream team']
# ['guardian.co.tt', 'attorney kareem marcelle announces intent to screen for laventille west 6.2.2149923.f2d078500d']
# ['thenationonlineng.net', 'fubara wike and the niger delta threat']
# ['morningsun.net', 'help protect yourself against pneumococcal pneumonia and invasive pneumococcal disease this,160921']
# ['ibtimes.co.in', 'indian coast guard rescues critically ill seafarer liberian carrier mt babylon 874119']
# ['kcsufm.com', 'students at csu share thoughts on tuition increase ascsu works to combat bias and racism drop boxes catch fire']
# ['dailyexcelsior.com', 'batting will be challenging on third day wankhede pitch ajaz patel']
# ['times-series.co.uk', '24696765.harris trump zero sun belt states final weekend push votes']
# ['patriotla.iheart.com', '2024 11 02 woman convicted of murder while wearing clown mask released from prison']
# ['menafn.com', 'SingleView Showcases Transformative Open Banking Solutions at Seamless Saudi 2024']
# ['liverpoolecho.co.uk', 'two women killed south wales 30285858']
# ['dailykos.com', ' What is he alluding to']
# ['yasstribune.com.au', '?cs=34616']
# ['newburytoday.co.uk', 'jb gill and lauren oakley score joint series highest as amy dowden watches 131431']
# ['burytimes.co.uk', '24696758.africa holds special place heart says william earthshot ceremony']
# ['wpbf.com', '62787307']
# ['1150wima.iheart.com', '2024 11 02 jason kelce smashes someones phone after slur about travis']
# ['watoday.com.au', 'an invite to the chairman s lounge would perk anyone up but mps should pay for it 20241101 p5kn4g.html']
# ['yahoo.com', 'missing cedar city man died 213339113.html']
# ['yahoo.com', 'most americans hardly knew kamala 222730612.html']
# ['justjared.com', '20 stars you didnt realize were adopted including simone biles jamie foxx faith hill more 2']
# ['thenationonlineng.net', 'sule raising accountability transparency bar through lg autonomy']
# ['yasstribune.com.au', '?cs=34616']
# ['wflaorlando.iheart.com', '2024 09 10 the best political podcasts to listen to']
# ['menafn.com', 'JK Records Alarming Spike In Road Accidents']
# ['winnipegfreepress.com', 'harris makes unscheduled visit to new york city in the campaigns final days']
# ['dailyexcelsior.com', 'archaeologists unearth an ancient middle kingdom egyptian tomb in luxor']
# ['newsradio540.iheart.com', '2024 11 02 shark completely severs leg of surfer off coast of hawaii']
# ['sthelensstar.co.uk', '24696777.teenage boy charged attempted murder girl 13 stabbed near roadside']
# ['empireofthekop.com', 'slot reaction final whistle liverpool brighton']
# ['dailyexcelsior.com', 'terror incidents aimed to destabilise govt farooq']
# ['washingtontimes.com', 'trump detours virginia encourages ag jason miyares']
# ['saltlakecitysun.com', 'pentagon secrets leaker could face 17 years in prison']
# ['oberonreview.com.au', '?cs=34616']
# ['thecorner.eu', '117347']
# ['macleayargus.com.au', '?cs=305']
# ['morningsun.net', 'thorpedo anna caps sensational season with victory in the breeders cup distaff at del mar,160920']
# ['thedailystar.net', '7 du collleges students boycott classes exams two days 3743166']
# ['yahoo.com', 'metro police arrest 3 teen 205651277.html']
# ['gloucesteradvocate.com.au', '?cs=9676']
# ['rsn.net.au', '672061']
# ['vindy.com', 'downtown resident blasts letter on realty']
# ['thisisoxfordshire.co.uk', '24696777.teenage boy charged attempted murder girl 13 stabbed near roadside']
# ['reporterherald.com', 'taft work shifting focus from south to north of eisenhower in loveland']
# ['womanandhome.com', 'celebrities iconic looks']
# ['1490wosh.com', 'wisconsin couple marks airbnbs two billionth guest milestone']
# ['cookislandsnews.com', 'diwali celebrated in rarotonga']
# ['newsnationnow.com', 'harris trump issue appeal to americans abroad in bid for more votes in tight race']
# ['menafn.com', 'Hope4hardship Names Almeida Co Founder']
# ['mymagic97.iheart.com', '2024 09 10 the best political podcasts to listen to']
# ['liverpoolecho.co.uk', 'winning lotto numbers tonight national 30250498']
# ['wcsy.com', 'dnr cautions about wildfire risk']
# ['pressofatlanticcity.com', 'article 9f142fe6 994c 11ef 8cb9 2b7a64959166.html']
# ['channelstv.com', 'psg fight to extend lead atop of ligue 1 with lens win']
# ['irishnews.com', 'review the vanishing elephant at the grand opera house belfast EW3IT56RGNB3JNXWROMKP6UY7U']
# ['1150wima.iheart.com', '2024 11 02 national guard on standby in several states for potential election unrest']
# ['krwg.org', 'crisis in haiti 1730578924']
# ['globalnews.ca', 'bella thomson memorialized tattoo fundraiser']
# ['theconservativetreehouse.com', 'comment page 2']
# ['spoilertv.com', 'murder in small town episode 106.html']
# ['pjmedia.com', 'all politics is local vote no on these 11 atrocious ballot amendments n4933889']
# ['digitaljournal.com', 'article']
# ['kyma.com', 'balloons for the 98th macys thanksgiving parade take flight test']
# ['thenationonlineng.net', 'lost anchors maiduguri women bear bitter burden of september flood']
# ['theguardian.com', 'boy 14 charged with attempted after multiple stabbing of girl 13 near hull']
# ['thenationonlineng.net', 'respite in northwest as more terrorists bite the dust']
# ['legalnewsline.com', '665627084 justice mckenna contributes as volunteer justice pro tem in cnmi']
# ['themarketsdaily.com', 'stone ridge 2056 longevity income etf nysearcalfaq announces dividend of 0 08.html']
# ['theconservativetreehouse.com', 'comment page 4']
# ['thehindu.com', 'article68823957.ece']
# ['ewrestlingnews.com', 'kevin owens injured solo sikoa says he was supposed to beat roman reigns']
# ['newzealandstar.com', 'new zealand ajaz patel wants to bat for as long as possible on day 3 against india']
# ['thenational.scot', '24696695.royal estates earn millions nhs state school rents']
# ['seneweb.com', 'kaolack la coalition takku wallu recoit  n 454818.html']
# ['seneweb.com', 'kemi badenoch nouvelle cheffe des conser n 454805.html']
# ['reporterherald.com', 'val mccullough a kind man brought a camelot of compassion']
# ['theconservativetreehouse.com', 'very positive initial early voting data also ground reports and election issues 2024 reader feedback thread']
# ['androidheadlines.com', 'google execs in halloween costumes spoke to workers about jobs cuts.html']
# ['news.webindia123.com', '4252135.html']
# ['wkyt.com', 'ben beddoes forecast another stretch warmer temperatures way']
# ['dailykos.com', ' Texas bans Federal Elections monitors from polling places']
# ['swissinfo.ch', 'moldova claims russia plans to disrupt expatriate voting in sunday']
# ['liverpoolecho.co.uk', 'bbc strictlys amy dowden says 30285726']
# ['yakimaherald.com', 'article a386d016 9892 11ef a7a5 23173224c460.html']
# ['classy100.com', 'derek merrin to newsmax working to oust longtime liberal lawmaker']
# ['menafn.com', 'Solar Power Push JKB Partners KPDCL Offers Interest Friendly Loans To Consumers']
# ['1490wosh.com', 'driver in winneconne pursuit clocked speeding through residential intersections arrested for 4th owi']
# ['thevikingage.com', 'minnesota vikings add notable player to offense before week 9 vs colts']
# ['channelstv.com', 'harris trump go toe to toe in frenzied final campaign weekend 2']
# ['watoday.com.au', 'sashimi leftovers from last night does a dietitian approve of shaun micallef s lunch 20241014 p5ki7v.html']
# ['yahoo.com', 'most americans hardly knew kamala 222730330.html']
# ['getsurrey.co.uk', 'bowel cancer symptoms silent killer 30268483']
# ['bangkokpost.com', 'govt courts more japan tech cash']
# ['yahoo.com', 'bridgeport high school hosts first 212256808.html']
# ['krwg.org', 'news wrap 1730579585']
# ['watoday.com.au', 'wildest most offensive thing why cynthia erivo doesn t like your wicked fan art 20241031 p5kmsu.html']
# ['kyma.com', 'locals attend annual somerton corn festival this weekend']
# ['yahoo.com', 'fire crews knock down house 221505786.html']
# ['themarketsdaily.com', 'stone ridge 2051 inflation protected longevity income etf nysearcaliaf declares dividend of 0 08.html']
# ['foxbangor.com', 'article 69b0d592 ab10 586e 9aa9 e5e1e9e055d8.html']
# ['thenationonlineng.net', 'suspected herdsmen kill six in benue community']
# ['953wdae.iheart.com', '2024 11 02 jason kelce smashes someones phone after slur about travis']
# ['burytimes.co.uk', '24696765.harris trump zero sun belt states final weekend push votes']
# ['maldonandburnhamstandard.co.uk', '24696758.africa holds special place heart says william earthshot ceremony']
# ['metvmall.com', 'powertown wrestling junkyard dog 1980']
# ['almanacnews.com', 'menlo park celebrates halloween']
# ['asianage.com', 'up fire breaks out at a factory in ghaziabads sahibabad area 1835068']
# ['breitbart.com', 'democrat senator john fetterman tells rogan that trumps message has resonated in pennsylvania']
# ['yahoo.com', 'just sprung us homeless miamians 230129583.html']
# ['cagle.com', 'two eagles']
# ['953wdae.iheart.com', '2024 11 02 antoine winfield bucky irving among those questionable for chiefs game']
# ['foxnews.com', 'alex berenson why im voting donald j trump']
# ['wallstreet-online.de', '18662937 biogrowing showcases natural probiotic products at supplyside west the usa']
# ['isp.netscape.com', '89b1ab499e9cc371b9abbc037c01256e']
# ['ottawaherald.com', 'couple of plays doom braves in home finale']
# ['wpbf.com', '62793235']
# ['dailyexcelsior.com', 'no security lapses in terror attacks troops giving befitting reply to terrorists rajnath']
# ['gdnonline.com:443', 'Online support group aims to help Parkinson%E2%80%99s patients ']
# ['swissinfo.ch', '87940126']
# ['en.apa.az', 'split on economic policy puts germanys government at risk of collapse 452368']
# ['zerohedge.com', 'if trump dictator']
# ['southpeacenews.com', 'concerns include crime helipad and more mla hears']
# ['patriotla.iheart.com', '2024 11 02 shark completely severs leg of surfer off coast of hawaii']
# ['digitaljournal.com', 'article']
# ['khvhradio.iheart.com', '2024 11 02 national guard on standby in several states for potential election unrest']
# ['couriernews.com', 'article 7ba7c753 b2a7 5a6a a60e 3699f9a41245.html']
# ['menafn.com', 'Siam Paragon Bangkok International Fashion Week 2024 Unveils The Best Of Thai And Asian Creativity And Reaffirms Siam Paragon As The Number One Luxury Destination Media Outreach Newswire APAC']
# ['kval.com', 'israeli forces capture senior hezbollah operative in north lebanon']
# ['yahoo.com', 'community shelter hosts 29th annual 215029246.html']
# ['1490wosh.com', 'lewandowski to newsmax election a choice between prosperity debt']
# ['yahoo.com', 'republicans score victory georgia fight 213147913.html']
# ['wallstreet-online.de', '18662928 rosen a ranked and leading law firm encourages the toronto dominion bank investors to secure counsel before deadline securities class action td']
# ['globalnews.ca', 'saskatchewan rush training camp record invitees 2024']
# ['yahoo.com', 'amid record breaking 2024 early 232412844.html']
# ['times-series.co.uk', '24696688.royal estates to earn millions nhs armed forces state school rents']
# ['foxbangor.com', 'article 8a78f207 0eb5 521f ae4b 7f39dfbbdbbe.html']
# ['edmontonsun.com', 'ucp alberta policy resolutions passed']
# ['asianage.com', 'assam a passenger bus falls into a roadside ditch in karimganj district over 10 people injured 1835070']
# ['themarketsdaily.com', 'stone ridge 2054 inflation protected longevity income etf declares dividend of 0 08 nysearcaliak.html']
# ['wiba.iheart.com', '2024 11 02 national guard on standby in several states for potential election unrest']
# ['wkyt.com', 'fayette countians wait hours utilize in person early voting']
# ['patriotla.iheart.com', '2024 11 02 delivery driver rescues woman from her burning home']
# ['tricitynews.com', 'jamey lyn horth wessels wins edmonton ufc fight against ivana petrovic 9750198']
# ['thisisoxfordshire.co.uk', '24696758.africa holds special place heart says william earthshot ceremony']
# ['1490wosh.com', 'dick morris to newsmax harris running on not trump']
# ['yahoo.com', 'national sandwich day 2024 deals 183944674.html']
# ['953wdae.iheart.com', '2024 11 02 seminoles fall to north carolina']
# ['stokesentinel.co.uk', 'a34 live updates serious crash 9683786']
# ['1045thezone.com', 'transfer heavy cal meets cal state bakersfield in opener']
# ['wpbf.com', '62793347']
# ['seneweb.com', 'ousmane sonko quot l rsquo abrogation de n 454809.html']
# ['wpbf.com', '62791744']
# ['dailyexcelsior.com', 'biggest and most complete dinosaur skeleton to go on sale on november 16']
# ['seneweb.com', 'kolda risque de telescopage entre ousman n 454814.html']
# ['ypradio.org', 'trump and harris make last minute stops in north carolina']
# ['kpht955.iheart.com', '2024 09 10 the best political podcasts to listen to']
# ['thisisoxfordshire.co.uk', '24696765.harris trump zero sun belt states final weekend push votes']
# ['kcsufm.com', 'serene indie tracks dominate the airwaves while glimpses of intense noise pop awaken the halloween spirit']
# ['themarketsdaily.com', 'omniaverse reaches self reported market capitalization of 95123 65 omnia.html']
# ['kmjnow.com', 'gops boebert losing ground in colo house race']
# ['gloucesteradvocate.com.au', '?cs=305']
# ['ottawaherald.com', 'ottawa city employees embrace halloween 2024 with creative costumes']
# ['times-series.co.uk', '24696719.cps considers charging russell brand sex offence allegations']
# ['fourfourtwo.com', 'lionel messi in the group chat deandre yedlin explains what messi mania is like from the inside at inter miami']
# ['1490wosh.com', 'reports packers qb jordan love expected to play in divisional showdown with detroit']
# ['wvtf.org', 'citing the pandemic tgi fridays files for bankruptcy']
# ['burytimes.co.uk', '23299956.morning vet dr scott warns dog owners pet habits']
# ['seneweb.com', 'lutte contre la delinquance 419 individu n 454816.html']
# ['maldonandburnhamstandard.co.uk', '24696719.cps considers charging russell brand sex offence allegations']
# ['theguardian.com', 'ernie dingo a chihuahua is like a ball of fluff with demonic mannerisms']
# ['hulldailymail.co.uk', 'boy 14 charged attempted murder 9683788']
# ['fool.com', 'is ups stock a buy']
# ['yahoo.com', 'listen jeffrey epstein tapes donald 231014849.html']
# ['seneweb.com', 'bassirou diomaye faye sur les violences  n 454813.html']
# ['echo-news.co.uk', '24696731.jb gill lauren oakley score joint series highest amy dowden watches']
# ['yahoo.com', 'kyiv calls russia list ukrainian 232303867.html']
# ['khvhradio.iheart.com', '2024 11 02 woman convicted of murder while wearing clown mask released from prison']
# ['963starcountry.iheart.com', '2024 09 10 the best political podcasts to listen to']
# ['wflaorlando.iheart.com', '2024 11 02 national guard on standby in several states for potential election unrest']
# ['kyma.com', 'tim walz attends a canvassing event in las vegas']
# ['lithgowmercury.com.au', '?cs=34616']
# ['newzealandstar.com', 'australia pakistan bangladesh sri lanka register semi final spots in hong kong sixes 2024']
# ['ktxs.com', 'israeli forces capture senior hezbollah operative in north lebanon']
# ['kmbc.com', '62791773']
# ['ewrestlingnews.com', 'triple h says wwe running events in saudi arabia is here to stay']
# ['en.apa.az', 'protest rally against parliamentary elections outcome in tbilisi over 452367']
# ['vindy.com', 'retaliation at its finest by mill creek director']
# ['aero-news.net', 'EmailArticle.cfm?do=main.textpost&id=6B3ABA0B C02B 456E B209 9285551C6BF0']
# ['bostonherald.com', 'courtemanche obliterates field at frank mooney meet']
# ['sthelensstar.co.uk', '24696688.royal estates to earn millions nhs armed forces state school rents']
# ['dailykos.com', ' This Guy Is Falling The Sky Is Falling Mixed Messages']
# ['wyrk.com', 'brianna chickenfry zach bryan tattoo']
# ['bunburymail.com.au', '?cs=12208']
# ['post-journal.com', 'dr john rappole to discuss life migrations his own avian and human immigration']
# ['parisstaronline.com:443', 'sarnia walk a mile event raises awareness of domestic violences impact']
# ['khvhradio.iheart.com', '2024 11 02 delivery driver rescues woman from her burning home']
# ['themarketsdaily.com', 'richquack com price down 3 7 this week quack.html']
# ['morningsun.net', 'the nyc marathon is here your guide to following along with 50000 runners from home,160916']
# ['ksnblocal4.com', 'hastings honors veterans with parade downtown']
# ['liverpoolecho.co.uk', 'barclays completes 600m tesco bank 30285891']
# ['nbcrightnow.com', 'article d2066ed9 a24e 5b61 b22b 0102f04eab79.html']
# ['winnipegfreepress.com', 'vattiatos late td run helps middle tennessee beat utep 20 13']
# ['fool.com', 'is nu holdings stock a buy before nov 13']
# ['tivysideadvertiser.co.uk', '24696777.teenage boy charged attempted murder girl 13 stabbed near roadside']
# ['yahoo.com', '13th annual belington turkey trot 210646160.html']
# ['kcsufm.com', 'hhn 33 ending kasseys scare zone and house rankings']
# ['theadanews.com', 'article a160a08c 9888 11ef aded 6b13fd3af658.html']
# ['watoday.com.au', 'jackson graham p53651']
# ['qconline.com', 'article e977c8da b758 598d a5dc 68ca22868573.html']
# ['themarketsdaily.com', 'cms energy nysecms releases fy 2025 earnings guidance.html']
# ['leinsterexpress.ie', 'remains of infants found buried at famous laois church.html']
# ['newser.com', 'biden declares disaster in new mexico after floods.html']
# ['wknofm.org', 'trump and harris make last minute stops in north carolina']
# ['khvhradio.iheart.com', '2024 11 02 jason kelce smashes someones phone after slur about travis']
# ['ottawaherald.com', 'ou volleyball sweeps sterling']
# ['liverpoolecho.co.uk', 'strictly come dancing fans demand 30286071']
# ['dailyexcelsior.com', 'hindus in bangladesh rally to demand protection from attacks and harassment']
# ['kyma.com', 'over 100 pounds of fentanyl pills found at calexico port of entry']
# ['times-series.co.uk', '24675353.megans restaurant richmond old town hall review']
# ['nypost.com', 'who needs an endorsement media has been been biased for kamala harris from the start']
# ['sconeadvocate.com.au', '?cs=305']
# ['kval.com', 'post 911 veterans split between supporting harris trump 2024 election military vets politics iava']
# ['kmjnow.com', 'trump at n c rally our crime is through the roof']
# ['cbc.ca', 'pei remembrance day poppies wellington 1.7372009']
# ['liverpoolecho.co.uk', 'bbc strictly star chris mccauslands 30285954']
# ['fandompost.com', 'detectives these days are crazy anime gets new promo with cast expansion']
# ...
# ['theboneonline.com', 'A4KT44372WZSNPFSYHZ5JEVYBU']
# ['chronicleonline.com', 'image e5365f33 96f4 5247 89d9 818b6852a192.html']
# ['outlookindia.com', 'no exclusive friendships for vishwa mitra india in multi polar world s jaishankar']
# ['theenterpriseleader.com', 'whitecoin xwc price reaches 0 0130 on exchanges.html']
# ['politicalwire.com', 'rfk jr says trump will remove fluoride from water']
# ['witneygazette.co.uk', '24696804.kamala harris will appear snl presidential election']
# ['thehindu.com', 'article68823466.ece']
# ['egyptianstreets.com', 'carla davis']
# ['businesspost.ie', 'matt cooper 20 reasons why i want trump to lose']
# ['cravenherald.co.uk', '24696811.robert f kennedy jr says donald trump push remove fluoride water']
# ['politicalwire.com', 'about that iowa poll']
# ['outlookindia.com', '7 best night safaris in india for an adventurous experience']
# ['kristv.com', 'the 15th annual voices of south texas takes place at old bayview cemetery']
# ['mashable.com', 'wordle today answer november 3 2024']
# ['independent.co.uk', 'israel business hate crime london met police b2640393.html']
# ['wusa9.com', '65 8cbc1bb5 67cb 4d7f af47 e17ae3c83215']
# ['theenterpriseleader.com', 'federal signal nysefss updates fy24 earnings guidance.html']
# ['thenews.com.pk', '1246738 digital dominoes']
# ['wkrb13.com', 'bitdao price down 3 9 this week bit.html']
# ['screenrant.com', 'star wars the bad batch enhanced clones secret']
# ['atlantanewsfirst.com', 'georgia pulls off victory against florida despite 3 interceptions']
# ['chronicleonline.com', 'image 7886e540 0340 5fdf ba0f d87b53447d30.html']
# ['santacruzsentinel.com', 'hot rods at the beach car show celebrates 26 years at the santa cruz beach boardwalk']
# ['themarketsdaily.com', 'norwegian cruise line nysenclh issues fy24 earnings guidance.html']
# ['news.webindia123.com', '4252142.html']
# ['outlookindia.com', 'on the lack of objectivity and academic wastage in social science research']
# ['crooksandliars.com', 'cls late nite music club cass elliot and']
# ['witneygazette.co.uk', '24696796.firms 500m investment uk show confidence government   chancellor']
# ['hazard-herald.com', 'article 0e685005 a714 5be1 bff4 746ea6d26e5d.html']
# ['scmp.com', 'hong kong health tech start ups innovate digital wearables ageing population']
# ['drovers.com:443', 'beef perfect dietary protein']
# ['timesofindia.indiatimes.com', '114896597.cms']
# ['wfre.com', '?date post=83001']
# ['chronicleonline.com', 'article 982c943d 787b 52bf a134 413c540e21bc.html']
# ['krmg.com', 'FDUK3SJBMJB5ZBBE5IUYXN7TKA']
# ['chronicle.lu', '12726 rambert peaky blinders dance show']
# ['wusa9.com', '65 9a4f132d c9a5 4c0c a82a 1c0e311e82f6']
# ['1049thebeat.com', 'red raiders upset 11 iowa state on the road 23 22 for bowl eligibility']
# ['themarketsdaily.com', 'enviri nysenvri updates q4 earnings guidance.html']
# ['columbian.com', 'as israel strikes deeper into lebanon fear rises in communities where the displaced took refuge']
# ['americansongwriter.com', '4 of the most controversial banned songs ever pulled from radio']
# ['dailygazette.com', 'article cb0f566c 7c64 5ed5 b43b 1f948ded4753.html']
# ['theday.com', 'harris and trump focus on sunbelt states during final weekend push for votes']
# ['outlookindia.com', 'arup maharatna 2']
# ['wdsu.com', '62793764']
# ['screenrant.com', 'time cut easter eggs references hidden details']
# ['kunc.org', 'kamala harris is live from new york on saturday night live']
# ['khmertimeskh.com', 'siem reap touted to be top tourist destination for australians in 2025']
# ['thesun.my', 'harris trump hit overdrive in campaign s final weekend MD13233539']
# ['yahoo.com', 'us marshals round rock police 220707605.html']
# ['koco.com', '62793608']
# ['thewestmorlandgazette.co.uk', '24696795.kemi badenoch name shadow cabinet within days']
# ['timesofindia.indiatimes.com', '114896820.cms']
# ['darlingtonandstocktontimes.co.uk', '24696811.robert f kennedy jr says donald trump push remove fluoride water']
# ['darlingtonandstocktontimes.co.uk', '24696812.swing states likely decide result us election']
# ['koco.com', '62793764']
# ['local12.com', 'former newport high school custodian kentucky heartwarming homecoming surprise health issues wade cruse ramp hospitals nursing home']
# ['news.webindia123.com', '4252148.html']
# ['dailygazette.com', 'article 3a17f52a 989b 11ef be99 2f3de3ce7509.html']
# ['nwemail.co.uk', '24696795.kemi badenoch name shadow cabinet within days']
# ['nwemail.co.uk', '24696802.reeves insists labour will secure growth defends budget choices']
# ['evanstonnow.com', 'd65 enrollment continues to drop']
# ['stettlerindependent.com', 'team homan makes history as canadas first ever womens winners at pan continental championships 7625935']
# ['dawn.com', 'justice shah regrets lack of focus on climate change']
# ['euronews.com', 'volunteers clean up paiporta as pedro sanchez mobilises 10000 more troops']
# ['yahoo.com', 'harris county swat standoff ends 220632883.html']
# ['themarketsdaily.com', 'stp self reported market capitalization achieves 77 39 million stpt.html']
# ['dualshockers.com', 'remastering games series dragon age collection would be challenging']
# ['bbc.com', 'c9dll4jvpzvo']
# ['khmertimeskh.com', 'archaeologists discover 900 year old door guardian statues in cambodia']
# ['wusa9.com', '507 f957cc73 9a40 4d3e bbbc e115b9169efd']
# ['coincommunity.com', 'topic.asp?TOPIC ID=60961&whichpage=441']
# ['advocateanddemocrat.com', 'article e8984290 9980 11ef 9ad9 8f3828fceb25.html']
# ['advocateanddemocrat.com', 'article fdfc2bae 9982 11ef 9245 fb6e1125376a.html']
# ['businesspost.ie', 'editorial valencia floods show why we must act now on tackling climate change']
# ['idahopress.com', 'article fea06b48 07f0 55fe 98e3 bb55eec8d6be.html']
# ['thecitizen.co.tz', 'saccos growth steady but rural access still elusive 4809720']
# ['accesswdun.com', '1269896']
# ['chronicleonline.com', 'article 111e9ad6 cf2e 5429 be6c 42cad441631c.html']
# ['darlingtonandstocktontimes.co.uk', '24696802.reeves insists labour will secure growth defends budget choices']
# ['local12.com', 'infant dies left in car florida school 15 month old']
# ['eveningnews24.co.uk', '24696813.us election night unfold hour by hour']
# ['vikingsterritory.com', 'vikings defender hits ir']
# ['yahoo.com', 'injuries reported following 2 separate 012042576.html']
# ['thewestmorlandgazette.co.uk', '24696804.kamala harris will appear snl presidential election']
# ['weartv.com', 'vice president kamala harris to make appearance on saturday night live nbc maya rudolph presidential campaign election day november 5']
# ['krmg.com', 'DYLLSECOVJDYXMZIY6X7X6IIXQ']
# ['chattanoogan.com', 'Jim Sasse.aspx']
# ['crooksandliars.com', 'man faces 6 felonies after trying run over']
# ['theenterpriseleader.com', 'sleepless ai price reaches 0 33 ai.html']
# ['breakingnews.ie', 'robert f kennedy jr says donald trump would push to remove fluoride from water 1690548.html']
# ['wfre.com', 'kickin up a cure']
# ['kunc.org', 'its all about north carolina on the campaign trail with trump and harris saturday']
# ['starobserver.com.au', '233678']
# ['northbaynipissing.com', 'article ae0ff189 3e00 56c1 8c36 bdd6ad2a14ef.html']
# ['mdjonline.com', 'article 28353bfc b5f6 5659 883e b771dfedc056.html']
# ['cravenherald.co.uk', '24696812.swing states likely decide result us election']
# ['thewestmorlandgazette.co.uk', '24696813.us election night unfold hour by hour']
# ['nkinternet.wordpress.com', 'inspecting north koreas digital map app licensing api insights']
# ['thehindu.com', 'article68823957.ece']
# ['thesun.my', 'harris tops trump in iowa in latest des moines register poll HD13233567']
# ['wdsu.com', '62793367']
# ['chelmsfordweeklynews.co.uk', '24696795.kemi badenoch name shadow cabinet within days']
# ['dawn.com', 'mastung blast fir registered by ctd']
# ['brentwoodlive.co.uk', '24696812.swing states likely decide result us election']
# ['crooksandliars.com', 'national archivist removes references']
# ['advocateanddemocrat.com', 'article 26217fc4 9980 11ef b61c 83d764fb15c2.html']
# ['wflanews.iheart.com', '2024 11 02 gators fall to 2 georgia']
# ['allkpop.com', 'wayv announces november comeback with mini album frequency']
# ['shinetv.co.nz', 'church at home 3 november 2024']
# ['wmmq.com', 'michigan senate bean soup']
# ['forexcrunch.com', 'gbp usd weekly forecast boe and us election uncertainty']
# ['omaha.com', 'article 9b10f2c8 97c9 11ef 87ae b3bdfd1dc8cc.html']
# ['businesspost.ie', 'big techs questionable ai bet shareholders now asking if rather than when itll pay off']
# ['witneygazette.co.uk', '24696802.reeves insists labour will secure growth defends budget choices']
# ['christianitytoday.com', 'holidays']
# ['wjla.com', 'adams morgan fall porchfest musicians artists classic rock funk go go rap bluegrass classical pop northwest dc road closures neighborhood safety music event dmv dc maryland virginia']
# ['katherinetimes.com.au', 'cuts for student debt as labor targets young voters']
# ['komu.com', 'article 150fadee 995f 11ef 9e23 df9bbada3698.html']
# ['apnews.com', 'pentagon osprey crash 5a86751c8dcb33cef91cab1edc34e7ef']
# ['businesspost.ie', 'euronext access a game changing new market for irish businesses after years of missed chances']
# ['wcvb.com', '62793367']
# ['drovers.com:443', 'which presidential candidate would have biggest impact ag']
# ['timesofindia.indiatimes.com', '114896753.cms']
# ['theenterpriseleader.com', 'polygon matic hits 24 hour volume of 9 92 million.html']
# ['kbtx.com', 'holiday spending expected be an all time high this season']
# ['menafn.com', 'Royal Court Chief Checks On Royal Initiative Projects In Maan And Tafileh']
# ['knbr.com', 'reports packers qb jordan love expected to start vs lions']
# ['theenterpriseleader.com', 'p2p solutions foundation p2ps achieves self reported market capitalization of 410 26 billion.html']
# ['thebiglead.com', 'kevin garnett says the bulls must make a statue for people s champ']
# ['thenews.com.pk', '1246748 oil export']
# ['yahoo.com', 'ukraine calls moscow list pows 023100290.html']
# ['khmertimeskh.com', 'the cambodia trade expo cte will be kick off in december']
# ['mdjonline.com', 'article 7b586b59 a4a9 55b4 b7ec 3ec9b225c891.html']
# ['chelmsfordweeklynews.co.uk', '24696802.reeves insists labour will secure growth defends budget choices']
# ['wnewsj.com', 'nervous chilly groves kicks hurricane into next round of playoffs']
# ['atlantanewsfirst.com', 'georgia judge rejects gop lawsuit trying block counties accepting hand returned mail ballots']
# ['businesspost.ie', 'ireland and eu brace for damaging tax based trade war if trump elected president']
# ['register-herald.com', 'article c02abdba 3ebf 540b bcc0 a7f75134960f.html']
# ['knbr.com', 'report cody bellinger returning to cubs in 2025']
# ['chelmsfordweeklynews.co.uk', '24696812.swing states likely decide result us election']
# ['marketscreener.com', 'Ukraine holding back powerful Russian offensive Kyiv top commander says 48241527']
# ['thenews.com.pk', '1246746 lifeline of sindh']
# ['telegrafi.com', 'macja shikoi macet vizatimore qe hidheshin nga shkembi dhe vendosi ti imitonte ato']
# ['wcvb.com', '62793764']
# ['thewestmorlandgazette.co.uk', '24696812.swing states likely decide result us election']
# ['themarketsdaily.com', 'telcoin price reaches 0 0014 tel.html']
# ['edenmagnet.com.au', '?cs=14264']
# ['mashable.com', 'nyt connections hint answer today november 3']
# ['businesspost.ie', 'grafton group plots e350 million ma war chest after entering iberian market']
# ['thesun.my', 'tenggara bersatu dissolves as division chief committee members announce exit ED13233205']
# ['yahoo.com', 'bay county council aging held 011743837.html']
# ['theenterpriseleader.com', 'frontier self reported market cap achieves 8 38 million front.html']
# ['katherinetimes.com.au', 'pm rallies labor troops ahead of election showdown']
# ['kxxv.com', 'a few lingering showers into sunday']
# ['wmmq.com', 'speed limit public act 33 michigan']
# ['khmertimeskh.com', 'cambodia seizes 7 39 tonnes of narcotics during jan oct period of 2024']
# ['khmertimeskh.com', 'rains likely to continue for next couple of days turning to sunshine later']
# ['brewpublic.com', 'celebrate the holidays with portland cider co s cranberry mule and santas sauce']
# ['hawkesburygazette.com.au', '?cs=30776']
# ['dailyeasternnews.com', 'flowers scores three touchdowns in conference win over western illinois']
# ['marketscreener.com', 'Harris tops Trump in latest Iowa poll marking turnaround Des Moines Register survey 48241481']
# ['timesofindia.indiatimes.com', '114896858.cms']
# ['kdrv.com', 'article 6e3c52fe 9947 11ef b5b5 cb28ee94a56e.html']
# ['news-gazette.com', 'article 989e0395 0854 5f9f bef0 2f0f3541dc9d.html']
# ['chicagobears.com', 'roster moves bears activate larry borom off ir elevate two others']
# ['sdjewishworld.com', 'todays jewish birthday sofia polgar']
# ['housingwire.com', 'why home prices are holding steady despite higher rates']
# ['wabi.tv', 'narraguagus wins class c state volleyball championship']
# ['lovinmalta.com', 'the 2024 lovin malta social media awards nominees receive 50k votes in just 24 hours']
# ['themarketsdaily.com', 'binaryx trading down 13 over last week bnx.html']
# ['witneygazette.co.uk', '24696813.us election night unfold hour by hour']
# ['thesun.my', 'singaporean awarded s 475m after sustaining brain damage from collision on malaysian road in 2018 ED13233315']
# ['theriver973.iheart.com', '2024 09 10 the best political podcasts to listen to']
# ['outlookindia.com', 'madhya pradesh cms panel finds no conspiracy after 10 elephants die in bandhavgarh tiger reserve in 72 hours']
# ['mirrorspectator.com', 'time for israel to do whats right recognize armenian genocide establish embassy in yerevan']
# ['eveningnews24.co.uk', '24696811.robert f kennedy jr says donald trump push remove fluoride water']
# ['bernews.com', 'nov1nahki wells scores bristol city victory']
# ['pjmedia.com', 'is this the biggest suppression poll in history n4933899']
# ['giants.com', 'tomon fox greg joseph jude mcatamney jakob johnson week 9 washington commanders roster moves']
# ['eveningnews24.co.uk', '24696796.firms 500m investment uk show confidence government   chancellor']
# ['dailygazette.com', 'article 7c10bfb0 a683 5729 80b3 9cc15bf3906e.html']
# ['hometownstations.com', 'article 02c07d82 993a 11ef a816 ab6a4e192c61.html']
# ['themarketsdaily.com', 'rocket pool eth price up 0 4 over last week reth.html']
# ['nwemail.co.uk', '24696811.robert f kennedy jr says donald trump push remove fluoride water']
# ['hazard-herald.com', 'article b4fe5fc7 f9de 53a5 b7f8 6b55d24ec47e.html']
# ['thenews.com.pk', '1246745 26th amendment']
# ['coincommunity.com', 'topic.asp?TOPIC ID=422555&whichpage=60']
# ['nwemail.co.uk', '24696812.swing states likely decide result us election']
# ['forexcrunch.com', 'aud usd weekly forecast uncertainty ahead of election week']
# ['timesofindia.indiatimes.com', '114896575.cms']
# ['darlingtonandstocktontimes.co.uk', '24696813.us election night unfold hour by hour']
# ['businesspost.ie', 'private developers are risk averse the government needs to boost social housing bodies']
# ['shark1053.com', 'heres how much you need to live comfortably in massachusetts']
# ['menafn.com', 'Amit Shah To Release BJP Manifesto For Jharkhand Assembly Polls Today']
# ['screenrant.com', 'batman the animated series fight scenes']
# ['atlantanewsfirst.com', 'bummer reaches 13m 2 year deal with braves who guarantee additional 4m lpez']
# ['outlookindia.com', 'book excerpt tell me how it ends an essay in forty questions by valeria luiselli']
# ['politicalwire.com', 'harris to appear on saturday night live']
# ['outlookindia.com', '10 best places to see koalas on your australia trip']
# ['beat.com.au', 'david hirschfelder mindy meng wang collaboration concert']
# ['businesspost.ie', 'marion mckeone trump allies stoke fears of election day chaos in pennsylvania']
# ['yahoo.com', 'harris trump cross paths north 023404539.html']
# ['yahoo.com', 'pt cruiser driver dies 3 010754464.html']
# ['sdjewishworld.com', 'sdja high schoolers will show third graders how products are designed']
# ['tigernet.com', 'my god mafah is slow 2390797']
# ['cravenherald.co.uk', '24696813.us election night unfold hour by hour']

# %%
amounts = OP['amounts'].iloc[3].split(';') # For reference check the GDELT GKG Cookbook V2.1
print(amounts[0])
amt0 = amounts[0].split(',') # 3 components: amount, object, offset
print(f'The amount is {amt0[0]} with object "{amt0[1]}" at approximate character offset {amt0[2]} of the document.')
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 amounts = OP['amounts'].iloc[3].split(';') # For reference check the GDELT GKG Cookbook V2.1
#       2 print(amounts[0])
#       3 amt0 = amounts[0].split(',') # 3 components: amount, object, offset
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexing.py:1073, in _LocationIndexer.__getitem__(self, key)
#    1070 axis = self.axis or 0
#    1072 maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1073 return self._getitem_axis(maybe_callable, axis=axis)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexing.py:1625, in _iLocIndexer._getitem_axis(self, key, axis)
#    1622     raise TypeError("Cannot index by location index with a non-integer key")
#    1624 # validate the location
# -> 1625 self._validate_integer(key, axis)
#    1627 return self.obj._ixs(key, axis=axis)
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexing.py:1557, in _iLocIndexer._validate_integer(self, key, axis)
#    1555 len_axis = len(self.obj._get_axis(axis))
#    1556 if key >= len_axis or key < -len_axis:
# -> 1557     raise IndexError("single positional indexer is out-of-bounds")
#
# IndexError: single positional indexer is out-of-bounds

# %% [markdown]
# # GKG Field Parser
# Specifics for fields are in progress. Currently all the fields below work, as well as the version one types. The GKG Cookbook can be used for further field refinements within the `gkg_operator` class.

# %%
gkg.gkg_query.shape
# Out:
# (31349, 27)

# %%
# gkg.parse_gkg_field(OP, 'amounts')
# gkg.parse_gkg_field(OP, 'v2persons')
# gkg.parse_gkg_field(OP, 'v2themes')
# gkg.parse_gkg_field(OP, 'allnames')
# gkg.parse_gkg_field(OP, 'v2locations') #  (semicolon-delimited blocks, with pound symbol (“#”) delimited fields) 
# gkg.parse_gkg_field(OP, 'v2tone')
# gkg.parse_gkg_field(field='locations')
gkg.parse_gkg_field(data=gkg.gkg_query.iloc[:nrows,:],field='organizations')

# gkg.parse_gkg_field(data=gkg.gkg_query.iloc[:nrows,:],field='themes')
# Out:
#        index               organizations_0
# 0          0                  foxley hotel
# 1          0        foxley hotel in milton
# 2          1                        nissan
# 3          1                        toyota
# 4          1                         isuzu
# ...      ...                           ...
# 18124   9992  flinders chase national park
# 18125   9993           darebin arts center
# 18126   9995                 supreme court
# 18127   9997      san diego jewish academy
# 18128   9997                head of school
#
# [18129 rows x 2 columns]

# %%
job_op_idx = gkg.parsed_fields_df[gkg.parsed_fields_df['themes_0'].str.contains('JOB_OPPORT')]['index'].unique().tolist()
recent_jobs = gkg.gkg_query.iloc[job_op_idx,:]
recent_jobs.head()
# gkg.parsed_fields_df[gkg.parsed_fields_df['index'] == 0] # the last field is the charoffset
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'themes_0'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 job_op_idx = gkg.parsed_fields_df[gkg.parsed_fields_df['themes_0'].str.contains('JOB_OPPORT')]['index'].unique().tolist()
#       2 recent_jobs = gkg.gkg_query.iloc[job_op_idx,:]
#       3 recent_jobs.head()
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'themes_0'

# %% [markdown]
# # GKG Field Tokenization

# %%
gkg.tokenize_field(col_idx=1)
print(gkg.field_tokens[:5] + gkg.field_tokens[-5:])
print(len(gkg.field_tokens))
# Out:
# ['a bellingham city club', 'a conservative party', 'a court', 'a decade of building great technology', 'a department of health', 'zoe church', 'zoning commission', 'zoological society of london', 'zoominfo technologies inc', 'zoram people movement']
# 7003

# %% [markdown]
# # GKG Field Vectorizer

# %%
parsed_urls[:10]
# Out:
# ['hotel issues statement out control 9683785',
#  '?cs=34616',
#  '?cs=305',
#  'russian exiles push western countries to support ukraine',
#  'rep waltz to newsmax biden wh sends weapons doesnt contain iran',
#  '2111.08566',
#  '?cs=34616',
#  '24696787.russell brand sex offence allegations evidence sent cps',
#  'scientific soothsayers why us election polls are often right or spectacularly wrong 20241031 p5kmtx.html',
#  'donald trump holds rally gastonia 220710886.html']

# %%
# gkgvf = gkg.vectorize_field(data=OP)
gkgvf = gkg.vectorize_field(data=gkg.gkg_query.iloc[:nrows,:])
# gkgvf = gkg.vectorize_field(data=recent_jobs)
gkgvf.shape
# rename rows with urls
gkgvf.index = parsed_urls
gkgvf.head()
# Out:
# 1 is the field object column index
#                                                     a bellingham city club  \
# hotel issues statement out control 9683785                             0.0
# ?cs=34616                                                              0.0
# ?cs=305                                                                0.0
# russian exiles push western countries to suppor...                     0.0
# rep waltz to newsmax biden wh sends weapons doe...                     0.0
#
#                                                     a conservative party  \
# hotel issues statement out control 9683785                           0.0
# ?cs=34616                                                            0.0
# ?cs=305                                                              0.0
# russian exiles push western countries to suppor...                   0.0
# rep waltz to newsmax biden wh sends weapons doe...                   0.0
#
#                                                     a court  \
# hotel issues statement out control 9683785              0.0
# ?cs=34616                                               0.0
# ?cs=305                                                 0.0
# russian exiles push western countries to suppor...      0.0
# rep waltz to newsmax biden wh sends weapons doe...      0.0
#
#                                                     a decade of building great technology  \
# hotel issues statement out control 9683785                                            0.0
# ?cs=34616                                                                             0.0
# ?cs=305                                                                               0.0
# russian exiles push western countries to suppor...                                    0.0
# rep waltz to newsmax biden wh sends weapons doe...                                    0.0
#
#                                                     a department of health  \
# hotel issues statement out control 9683785                             0.0
# ?cs=34616                                                              0.0
# ?cs=305                                                                0.0
# russian exiles push western countries to suppor...                     0.0
# rep waltz to newsmax biden wh sends weapons doe...                     0.0
#
#                                                     a des moines register mediacom selzer co  \
# hotel issues statement out control 9683785                                               0.0
# ?cs=34616                                                                                0.0
# ?cs=305                                                                                  0.0
# russian exiles push western countries to suppor...                                       0.0
# rep waltz to newsmax biden wh sends weapons doe...                                       0.0
#
#                                                     a disaster recovery center  \
# hotel issues statement out control 9683785                                 0.0
# ?cs=34616                                                                  0.0
# ?cs=305                                                                    0.0
# russian exiles push western countries to suppor...                         0.0
# rep waltz to newsmax biden wh sends weapons doe...                         0.0
#
#                                                     a division  \
# hotel issues statement out control 9683785                 0.0
# ?cs=34616                                                  0.0
# ?cs=305                                                    0.0
# russian exiles push western countries to suppor...         0.0
# rep waltz to newsmax biden wh sends weapons doe...         0.0
#
#                                                     a finance department  \
# hotel issues statement out control 9683785                           0.0
# ?cs=34616                                                            0.0
# ?cs=305                                                              0.0
# russian exiles push western countries to suppor...                   0.0
# rep waltz to newsmax biden wh sends weapons doe...                   0.0
#
#                                                     a fragmented community  \
# hotel issues statement out control 9683785                             0.0
# ?cs=34616                                                              0.0
# ?cs=305                                                                0.0
# russian exiles push western countries to suppor...                     0.0
# rep waltz to newsmax biden wh sends weapons doe...                     0.0
#
#                                                     ...  \
# hotel issues statement out control 9683785          ...
# ?cs=34616                                           ...
# ?cs=305                                             ...
# russian exiles push western countries to suppor...  ...
# rep waltz to newsmax biden wh sends weapons doe...  ...
#
#                                                     zifa matabeleland south division two league  \
# hotel issues statement out control 9683785                                                  0.0
# ?cs=34616                                                                                   0.0
# ?cs=305                                                                                     0.0
# russian exiles push western countries to suppor...                                          0.0
# rep waltz to newsmax biden wh sends weapons doe...                                          0.0
#
#                                                     ziff davis  \
# hotel issues statement out control 9683785                 0.0
# ?cs=34616                                                  0.0
# ?cs=305                                                    0.0
# russian exiles push western countries to suppor...         0.0
# rep waltz to newsmax biden wh sends weapons doe...         0.0
#
#                                                     zimbabwe confederation of public sector trade unions  \
# hotel issues statement out control 9683785                                                        0.0
# ?cs=34616                                                                                         0.0
# ?cs=305                                                                                           0.0
# russian exiles push western countries to suppor...                                                0.0
# rep waltz to newsmax biden wh sends weapons doe...                                                0.0
#
#                                                     zimbabwe republic police  \
# hotel issues statement out control 9683785                               0.0
# ?cs=34616                                                                0.0
# ?cs=305                                                                  0.0
# russian exiles push western countries to suppor...                       0.0
# rep waltz to newsmax biden wh sends weapons doe...                       0.0
#
#                                                     zion national park  \
# hotel issues statement out control 9683785                         0.0
# ?cs=34616                                                          0.0
# ?cs=305                                                            0.0
# russian exiles push western countries to suppor...                 0.0
# rep waltz to newsmax biden wh sends weapons doe...                 0.0
#
#                                                     zoe church  \
# hotel issues statement out control 9683785                 0.0
# ?cs=34616                                                  0.0
# ?cs=305                                                    0.0
# russian exiles push western countries to suppor...         0.0
# rep waltz to newsmax biden wh sends weapons doe...         0.0
#
#                                                     zoning commission  \
# hotel issues statement out control 9683785                        0.0
# ?cs=34616                                                         0.0
# ?cs=305                                                           0.0
# russian exiles push western countries to suppor...                0.0
# rep waltz to newsmax biden wh sends weapons doe...                0.0
#
#                                                     zoological society of london  \
# hotel issues statement out control 9683785                                   0.0
# ?cs=34616                                                                    0.0
# ?cs=305                                                                      0.0
# russian exiles push western countries to suppor...                           0.0
# rep waltz to newsmax biden wh sends weapons doe...                           0.0
#
#                                                     zoominfo technologies inc  \
# hotel issues statement out control 9683785                                0.0
# ?cs=34616                                                                 0.0
# ?cs=305                                                                   0.0
# russian exiles push western countries to suppor...                        0.0
# rep waltz to newsmax biden wh sends weapons doe...                        0.0
#
#                                                     zoram people movement
# hotel issues statement out control 9683785                            0.0
# ?cs=34616                                                             0.0
# ?cs=305                                                               0.0
# russian exiles push western countries to suppor...                    0.0
# rep waltz to newsmax biden wh sends weapons doe...                    0.0
#
# [5 rows x 7003 columns]

# %%
gkg.vectorized_df.sum(axis=0).sort_values(ascending=False).head(20)
# Out:
# united states                         546.0
# associated press                      436.0
# twitter                               341.0
# white house                           282.0
# facebook                              282.0
# new york times                        246.0
# instagram                             221.0
# right center                          169.0
# detroit lions                         152.0
# atlanta civic center                  130.0
# cnn                                   128.0
# youtube                               107.0
# supreme court                         103.0
# espn                                   89.0
# national planning policy framework     87.0
# prologis                               87.0
# laboratory of molecular biology        86.0
# foreign office                         82.0
# drug administration                    80.0
# national institutes of health          79.0
# dtype: float64

# %%
# Desired column names
target_columns = ['one piece', 'sun god', 'devil fruit','one piece fan letter', 'egghead island',
                   'artificial intelligence', 'microsoft','msft','nuclear', 'ge vernova', 'data science', 'python','ai', 'data']
# test business organizations
target_columns = ['microsoft', 'microsoft corporation', 'microsoft corp', 'msft',
                  'ibm', 'international business machines', 'ibm corp', 'ibm corporation',
                  'apple', 'apple inc', 'apple corporation',
                  'google', 'google inc', 'google corporation',]

# test political parties
target_columns = ['supreme court', 'democratic party', 'republican party', 'green party', 'libertarian party',]

# Get the intersection of target columns and actual columns in the DataFrame
existing_columns = gkg.vectorized_df.columns.intersection(target_columns)

# Subset the DataFrame to only include the existing columns
result_df = gkg.vectorized_df[existing_columns].copy()
# only show non-zero records
result_df = result_df[result_df.sum(axis=1) > 0]
result_df
result_df[result_df['green party'] > 0].head()
# Out:
#                                                     democratic party  \
# harris widens lead trump virginia 204331061.html                 0.0
# harris widens lead trump virginia 204313786.html                 0.0
# ae0a2d7d 6713 4864 a3f4 ce2f55fe05f6                             0.0
# article 827278                                                   0.0
# undecided voters us election 2024 kamala harris...               1.0
#
#                                                     green party  \
# harris widens lead trump virginia 204331061.html            1.0
# harris widens lead trump virginia 204313786.html            1.0
# ae0a2d7d 6713 4864 a3f4 ce2f55fe05f6                        1.0
# article 827278                                              1.0
# undecided voters us election 2024 kamala harris...          1.0
#
#                                                     republican party  \
# harris widens lead trump virginia 204331061.html                 0.0
# harris widens lead trump virginia 204313786.html                 0.0
# ae0a2d7d 6713 4864 a3f4 ce2f55fe05f6                             0.0
# article 827278                                                   0.0
# undecided voters us election 2024 kamala harris...               0.0
#
#                                                     supreme court
# harris widens lead trump virginia 204331061.html              0.0
# harris widens lead trump virginia 204313786.html              0.0
# ae0a2d7d 6713 4864 a3f4 ce2f55fe05f6                          0.0
# article 827278                                                0.0
# undecided voters us election 2024 kamala harris...            0.0

# %%
# what columns are non-zero for the rows missing the 'one piece' token
# gkg.vectorized_df[gkg.vectorized_df['one piece'] == 0].iloc[1].value_counts()
# gkg.vectorized_df[gkg.vectorized_df['one piece'] == 0].sum(axis=0).sort_values(ascending=False).head(20)

# %% [markdown]
# # GKG Tools Get Soup

# %%
gkg.get_gkg_soup(urls[6])

# %%
for url in urls[:10]:
    print(urls.index(url))
    gkg.parse_gkg_soup(url,verbose=True)
# Out:
# 0
# Title: Hotel issues statement as out-of-control bonfire spreads to caravan - Stoke-on-Trent Live
# No text bounds set for this URL
# Length of Header List: 3
# First Header: Hotel issues statement as out-of-control bonfire spreads to caravan
# Last Header: Follow usFollow us
# Length of Paragraph List: 11
# First Paragraph: Want Stoke-on-Trent news emailed to you direct from our journalists? Sign up to our newsletter
# Last Paragraph: Get daily headlines and breaking news emailed to you - it’s FREE
#
#
# 1
# Title: Which off-road ready ute would you buy? | Lithgow Mercury | Lithgow, NSW
# No text bounds set for this URL
# Length of Header List: 20
# First Header: Which off-road ready ute would you buy?
# Last Header: William Stopford: Ford Ranger Raptor
# Length of Paragraph List: 67
# First Paragraph: Your digital subscription includes access to content from all our websites in your region.
# Access unlimited content and the digital versions of our print editions - Today's Paper.
# Last Paragraph: Advertisement
#
#
# 2
# Title: Teen critical after M1 head-on crash in Lake Macquarie | The Scone Advocate | Scone, NSW
# No text bounds set for this URL
# Length of Header List: 13
# First Header: Teenage driver critical after head-on crash on the M1
# Last Header: Sage Swinton
# Length of Paragraph List: 16
# First Paragraph: Your digital subscription includes access to content from all our websites in your region.
# Access unlimited content and the digital versions of our print editions - Today's Paper.
# Last Paragraph: Advertisement
#
#
# 3
# Title: Russian exiles push Western countries to support Ukraine | WKNO FM
# No text bounds set for this URL
# Length of Header List: 1
# First Header:
#         Russian exiles push Western countries to support Ukraine
#
# Last Header:
#         Russian exiles push Western countries to support Ukraine
#
# Length of Paragraph List: 21
# First Paragraph: SCOTT DETROW, HOST:
# Last Paragraph: NPR transcripts are created on a rush deadline by an NPR contractor. This text may not be in its final form and may be updated or revised in the future. Accuracy and availability may vary. The authoritative record of NPR’s programming is the audio record.
#
#
# 4
# Title: Rep. Waltz to Newsmax: Biden WH Sends Weapons, Doesn’t Contain Iran | WXKC-FM
# No text bounds set for this URL
# Length of Header List: 9
# First Header: Rep. Waltz to Newsmax: Biden WH Sends Weapons, Doesn’t Contain Iran
# Last Header: The Secret Cooking Ingredient Greeks Use for Longevity
# Length of Paragraph List: 6
# First Paragraph: The United States is spending billions in the defense of Israel without pushing to contain Iran, the “head of the snake” affecting the Middle East, Rep. Mike Waltz said on Newsmax Saturday.
# Last Paragraph: View Full Site
#
#
# 5
# Title: [2111.08566] SPANN: Highly-efficient Billion-scale Approximate Nearest Neighbor Search
# No text bounds set for this URL
# Length of Header List: 14
# First Header: Computer Science > Databases
# Last Header: Bookmark
# Length of Paragraph List: 5
# First Paragraph: Help|Advanced Search
# Last Paragraph: arXiv Operational StatusGet status notifications viaemailorslack
#
#
# 6
# Title: Which off-road ready ute would you buy? | Yass Tribune | Yass, NSW
# No text bounds set for this URL
# Length of Header List: 27
# First Header: Which off-road ready ute would you buy?
# Last Header: William Stopford: Ford Ranger Raptor
# Length of Paragraph List: 67
# First Paragraph: Your digital subscription includes access to content from all our websites in your region. Access unlimited content and the digital versions of our print editions - Today's Paper.
# Last Paragraph: Advertisement
#
#
# 7
# Title: Russell Brand sex offence allegations evidence sent to CPS | Echo
# No text bounds set for this URL
# Length of Header List: 15
# First Header: Russell Brand sex offence allegations evidence sent to CPS
# Last Header: Modal headline
# Length of Paragraph List: 20
# First Paragraph: Police investigating historic sex offence allegations against comedian and TV personality Russell Brand have sent evidence to the Crown Prosecution Service (CPS).
# Last Paragraph: It is important that we continue to promote these adverts as our local businesses need as much support as possible during these challenging times.
#
#
# 8
# Title: US election polls 2024: What’s the point of them?
# No text bounds set for this URL
# Length of Header List: 17
# First Header: ‘Scientific soothsayers’: Why US election polls are often right – or spectacularly wrong
# Last Header: Products & Services
# Length of Paragraph List: 58
# First Paragraph: We’re sorry, this feature is currently unavailable. We’re working to restore it. Please try again later.
# Last Paragraph: Copyright ©2024
#
#
# 9
# Title: Donald Trump holds rally in Gastonia hours before early voting ends
# No text bounds set for this URL
# Length of Header List: 8
# First Header: Donald Trump holds rally in Gastonia hours before early voting ends
# Last Header: New on Yahoo
# Length of Paragraph List: 15
# First Paragraph: Former President Donald Trump spoke at Gastonia’s airport hours before early voting ended in North Carolina.
# Last Paragraph: VIDEO: North Carolina breaks early voting record

# %% [markdown]
# # GKGSoup

# %%
from gkg_soup import GKGSoup
gkgsoup = GKGSoup()
for url in urls[:4]:
    # gkg.parse_gkg_soup(url,verbose=True)
    gkgsoup.parse_gkg_soup(url,verbose=True)
# Out:
# Title: Hotel issues statement as out-of-control bonfire spreads to caravan - Stoke-on-Trent Live
# No text bounds set for this URL
# Length of Header List: 3
# First Header: Hotel issues statement as out-of-control bonfire spreads to caravan
# Last Header: Follow usFollow us
# Length of Paragraph List: 11
# First Paragraph: Want Stoke-on-Trent news emailed to you direct from our journalists? Sign up to our newsletter
# Last Paragraph: Get daily headlines and breaking news emailed to you - it’s FREE
#
#
# Title: Which off-road ready ute would you buy? | Lithgow Mercury | Lithgow, NSW
# No text bounds set for this URL
# Length of Header List: 20
# First Header: Which off-road ready ute would you buy?
# Last Header: William Stopford: Ford Ranger Raptor
# Length of Paragraph List: 67
# First Paragraph: Your digital subscription includes access to content from all our websites in your region.
# Access unlimited content and the digital versions of our print editions - Today's Paper.
# Last Paragraph: Advertisement
#
#
# Title: Teen critical after M1 head-on crash in Lake Macquarie | The Scone Advocate | Scone, NSW
# No text bounds set for this URL
# Length of Header List: 13
# First Header: Teenage driver critical after head-on crash on the M1
# Last Header: Sage Swinton
# Length of Paragraph List: 16
# First Paragraph: Your digital subscription includes access to content from all our websites in your region.
# Access unlimited content and the digital versions of our print editions - Today's Paper.
# Last Paragraph: Advertisement
#
#
# Title: Russian exiles push Western countries to support Ukraine | WKNO FM
# No text bounds set for this URL
# Length of Header List: 1
# First Header:
#         Russian exiles push Western countries to support Ukraine
#
# Last Header:
#         Russian exiles push Western countries to support Ukraine
#
# Length of Paragraph List: 21
# First Paragraph: SCOTT DETROW, HOST:
# Last Paragraph: NPR transcripts are created on a rush deadline by an NPR contractor. This text may not be in its final form and may be updated or revised in the future. Accuracy and availability may vary. The authoritative record of NPR’s programming is the audio record.
